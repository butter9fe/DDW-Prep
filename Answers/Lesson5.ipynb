# %% [markdown]
# # Python Dictionaries
#
# Learn how to work with dictionaries - Python's most powerful data structure for storing and organizing data using key-value pairs.

# %% [markdown]
# ## Introduction to Dictionaries
#
# A dictionary is a collection of key-value pairs enclosed in curly braces `{}`. Dictionaries:
# - Store data as pairs: `key: value`
# - Are **mutable** (can be modified)
# - Use **keys** to access values (not indices like lists)
# - Have **unordered** items (in Python 3.7+, insertion order is preserved)
# - Are **indexed** by keys (which must be unique)
#
# Dictionaries are ideal for storing related information together with descriptive labels.

# %% [markdown]
# ### Basic Dictionary Operations

# %%
# Creating a simple dictionary
d = {"apple": 3, "orange": 2, "banana": 1}
print(d)
# Out:
# {'apple': 3, 'orange': 2, 'banana': 1}

# %% [markdown]
# ### Accessing Dictionary Values
#
# There are two main ways to access values in a dictionary.

# %%
d = {"apple": 3, "orange": 2, "banana": 1}

# Method 1: Using square brackets []
print(f"Apples: {d['apple']}")  # Output: 3

# Method 2: Using .get() method
print(f"Oranges: {d.get('orange')}")  # Output: 2

# .get() with a default value (safer!)
print(f"Mangoes: {d.get('mango', 'N/A')}")  # Output: N/A

# Why is .get() better?
# If you use d['mango'] and 'mango' doesn't exist, you'll get a KeyError
# With .get(), you can provide a default value instead
print(f"\n.get() is safer when keys might not exist!")
# Out:
# Apples: 3
# Oranges: 2
# Mangoes: N/A
#
# .get() is safer when keys might not exist!

# %% [markdown]
# ### Nested Dictionaries
#
# Dictionaries can contain other dictionaries, allowing you to store complex, hierarchical data.

# %%
# Dictionary containing dictionaries
students = {
    "alice": {"age": 20, "grade": "A"},
    "bob": {"age": 21, "grade": "B"}
}

# Accessing nested values
print(f"Alice's age: {students['alice']['age']}")  # Output: 20
print(f"Bob's grade: {students['bob']['grade']}")  # Output: B

# Print all students
print(f"\nAll students: {students}")
# Out:
# Alice's age: 20
# Bob's grade: B
#
# All students: {'alice': {'age': 20, 'grade': 'A'}, 'bob': {'age': 21, 'grade': 'B'}}

# %% [markdown]
# ## Modifying Dictionaries
#
# Dictionaries are mutable, so you can add, update, and remove key-value pairs.

# %% [markdown]
# ### Adding and Updating Keys

# %%
student = {"name": "Alice", "age": 20}
print(f"Initial: {student}")

# Update existing key
student["age"] = 22
print(f"After updating age: {student}")

# Add a new key
student["gender"] = "Female"
print(f"After adding gender: {student}")

# Add multiple keys
student["grade"] = "A"
print(f"After adding grade: {student}")
# Out:
# Initial: {'name': 'Alice', 'age': 20}
# After updating age: {'name': 'Alice', 'age': 22}
# After adding gender: {'name': 'Alice', 'age': 22, 'gender': 'Female'}
# After adding grade: {'name': 'Alice', 'age': 22, 'gender': 'Female', 'grade': 'A'}

# %% [markdown]
# ### Deleting Keys

# %%
student = {"name": "Alice", "age": 22, "grade": "A", "gender": "Female"}
print(f"Initial: {student}")

# Method 1: Using del
del student["grade"]
print(f"After del student['grade']: {student}")

# Method 2: Using .pop() - removes and returns the value
removed_gender = student.pop("gender")
print(f"\nRemoved gender: {removed_gender}")
print(f"After pop: {student}")

# Method 3: Using .popitem() - removes the last inserted item
student["city"] = "New York"
print(f"\nBefore popitem: {student}")
last_item = student.popitem()
print(f"Removed last item: {last_item}")
print(f"After popitem: {student}")
# Out:
# Initial: {'name': 'Alice', 'age': 22, 'grade': 'A', 'gender': 'Female'}
# After del student['grade']: {'name': 'Alice', 'age': 22, 'gender': 'Female'}
#
# Removed gender: Female
# After pop: {'name': 'Alice', 'age': 22}
#
# Before popitem: {'name': 'Alice', 'age': 22, 'city': 'New York'}
# Removed last item: ('city', 'New York')
# After popitem: {'name': 'Alice', 'age': 22}

# %% [markdown]
# ## More Dictionary Methods
#
# Dictionaries have several useful built-in methods for accessing different parts of the dictionary.

# %% [markdown]
# ### .keys(), .values(), and .items()

# %%
student = {"name": "Alice", "age": 20, "grade": "A"}

# .keys() - returns all keys
print(f"Keys: {student.keys()}")
# Output: dict_keys(['name', 'age', 'grade'])

# .values() - returns all values
print(f"\nValues: {student.values()}")
# Output: dict_values(['Alice', 20, 'A'])

# .items() - returns all key-value pairs as tuples
print(f"\nItems: {student.items()}")
# Output: dict_items([('name', 'Alice'), ('age', 20), ('grade', 'A')])
# Out:
# Keys: dict_keys(['name', 'age', 'grade'])
#
# Values: dict_values(['Alice', 20, 'A'])
#
# Items: dict_items([('name', 'Alice'), ('age', 20), ('grade', 'A')])

# %% [markdown]
# ### Other Useful Dictionary Methods

# %%
student = {"name": "Alice", "age": 20, "grade": "A"}

# .clear() - removes all items
# student.clear()  # Uncomment to see it in action

# .copy() - creates a shallow copy
student_copy = student.copy()
print(f"Copy: {student_copy}")

# .update() - adds/updates multiple key-value pairs
student.update({"age": 21, "city": "New York"})
print(f"\nAfter update: {student}")

# .setdefault() - gets a value or sets a default if key doesn't exist
phone = student.setdefault("phone", "N/A")
print(f"\nPhone (using setdefault): {phone}")
print(f"Dictionary after setdefault: {student}")

# Check if key exists
print(f"\n'age' in student: {'age' in student}")
print(f"'email' in student: {'email' in student}")
# Out:
# Copy: {'name': 'Alice', 'age': 20, 'grade': 'A'}
#
# After update: {'name': 'Alice', 'age': 21, 'grade': 'A', 'city': 'New York'}
#
# Phone (using setdefault): N/A
# Dictionary after setdefault: {'name': 'Alice', 'age': 21, 'grade': 'A', 'city': 'New York', 'phone': 'N/A'}
#
# 'age' in student: True
# 'email' in student: False

# %% [markdown]
# ## Iterating Through Dictionaries
#
# There are multiple ways to loop through a dictionary, each useful for different situations.

# %% [markdown]
# ### Iterating Through Keys

# %%
student = {"name": "Alice", "age": 20, "grade": "A"}

# Method 1: Direct iteration (iterates through keys)
for key in student:
    print(f"{key}: {student[key]}")

# Method 2: Using .keys() explicitly
print("\nUsing .keys():")
for key in student.keys():
    print(f"{key}: {student[key]}")

# Expected output:
# name: Alice
# age: 20
# grade: A
# Out:
# name: Alice
# age: 20
# grade: A
#
# Using .keys():
# name: Alice
# age: 20
# grade: A

# %% [markdown]
# ### Iterating Through Values

# %%
student = {"name": "Alice", "age": 20, "grade": "A"}

# Using .values() - only get the values
for value in student.values():
    print(value)

# Expected output:
# Alice
# 20
# A
# Out:
# Alice
# 20
# A

# %% [markdown]
# ### Iterating Through Key-Value Pairs (Recommended)

# %%
student = {"name": "Alice", "age": 20, "grade": "A"}

# Using .items() with tuple unpacking - most Pythonic way
for key, value in student.items():
    print(f"{key}: {value}")

# Expected output:
# name: Alice
# age: 20
# grade: A

print("\n.items() is the most readable and recommended approach!")
# Out:
# name: Alice
# age: 20
# grade: A
#
# .items() is the most readable and recommended approach!

# %% [markdown]
# ### Practical Example: Character Frequency Counter
#
# A common use case for dictionaries is counting occurrences.

# %%
# Count character frequencies in a string
text = "banana"
freq = {}

for char in text:
    # .get(char, 0) returns the count if it exists, or 0 if it doesn't
    freq[char] = freq.get(char, 0) + 1

print(f"Original text: {text}")
print(f"Character frequencies: {freq}")
# Expected output: {'b': 1, 'a': 3, 'n': 2}

# Display results nicely
print("\nCharacter frequencies:")
for char, count in freq.items():
    print(f"'{char}' appears {count} time(s)")
# Out:
# Original text: banana
# Character frequencies: {'b': 1, 'a': 3, 'n': 2}
#
# Character frequencies:
# 'b' appears 1 time(s)
# 'a' appears 3 time(s)
# 'n' appears 2 time(s)

# %% [markdown]
# ## Practical Examples
#
# Let's explore real-world use cases for dictionaries.

# %% [markdown]
# ### Example 1: Student Grades Management

# %%
# Managing student grades
students = {
    "Alice": {"math": 95, "english": 88, "science": 92},
    "Bob": {"math": 87, "english": 91, "science": 85},
    "Charlie": {"math": 92, "english": 89, "science": 94}
}

# Find the average grade for each student
for student_name, grades in students.items():
    average = sum(grades.values()) / len(grades)
    print(f"{student_name}'s average grade: {average:.2f}")

# Find the student with the highest math grade
highest_math = max(students.items(), key=lambda x: x[1]["math"])
print(f"\nHighest math grade: {highest_math[0]} with {highest_math[1]['math']}")
# Out:
# Alice's average grade: 91.67
# Bob's average grade: 87.67
# Charlie's average grade: 91.67
#
# Highest math grade: Alice with 95

# %% [markdown]
# ### Example 2: Product Inventory

# %%
# Product inventory
inventory = {
    "apples": 50,
    "oranges": 30,
    "bananas": 25,
    "grapes": 40
}

# Add new products
inventory["mangoes"] = 15

# Update inventory
inventory["apples"] -= 10  # Sell 10 apples

# Display inventory
print("Current Inventory:")
total = 0
for product, quantity in inventory.items():
    print(f"{product.capitalize()}: {quantity}")
    total += quantity
print(f"Total items: {total}")
# Out:
# Current Inventory:
# Apples: 40
# Oranges: 30
# Bananas: 25
# Grapes: 40
# Mangoes: 15
# Total items: 150

# %% [markdown]
# ### Question 1: Creating and Accessing Dictionaries
# Create a dictionary representing a student with keys: name, age, grade, and GPA. Add your own values and access each value using bracket notation.

# %%
# Question 1: Creating and Accessing Dictionaries
# Create a student dictionary and access its values

student = {
    "name": "Alice",
    "age": 20,
    "grade": "A",
    "GPA": 3.8
}

# Access each value using bracket notation
print(f"Name: {student['name']}")
print(f"Age: {student['age']}")
print(f"Grade: {student['grade']}")
print(f"GPA: {student['GPA']}")
# Out:
# Name: Alice
# Age: 20
# Grade: A
# GPA: 3.8

# %% [markdown]
# ### Question 2: Using .get() Method
# Using the student dictionary from Question 1:
# - Use `.get()` to access the "name" key
# - Use `.get()` with a default value to access a key that doesn't exist (like "major")

# %%
# Question 2: Using .get() Method
# Use .get() to safely access dictionary values

student = {
    "name": "Alice",
    "age": 20,
    "grade": "A",
    "GPA": 3.8
}

# Use .get() to access existing key
name = student.get("name")
print(f"Name: {name}")

# Use .get() with default value for missing key
major = student.get("major", "Not specified")
print(f"Major: {major}")
# Out:
# Name: Alice
# Major: Not specified

# %% [markdown]
# ### Question 3: Adding and Modifying Items
# Create an empty dictionary `inventory = {}`. Then:
# - Add three items with their quantities (e.g., "apples": 5, "oranges": 3)
# - Update the quantity of one item
# - Print the entire dictionary

# %%
# Question 3: Adding and Modifying Items
# Create an empty dictionary and add/modify items

inventory = {}

# Add items with quantities
inventory["apples"] = 5
inventory["oranges"] = 3
inventory["bananas"] = 7

print(f"Initial inventory: {inventory}")

# Update quantity of one item
inventory["apples"] = 8
print(f"Updated inventory: {inventory}")
# Out:
# Initial inventory: {'apples': 5, 'oranges': 3, 'bananas': 7}
# Updated inventory: {'apples': 8, 'oranges': 3, 'bananas': 7}

# %% [markdown]
# ### Question 4: Nested Dictionaries
# Create a nested dictionary representing a person with their contact information:
# ```
# person = {
#     "name": "Alice",
#     "contact": {"email": "alice@email.com", "phone": "123-456-7890"}
# }
# ```
# Access and print the email address.

# %%
# Question 4: Nested Dictionaries
# Access values from a nested dictionary

person = {
    "name": "Alice",
    "contact": {"email": "alice@email.com", "phone": "123-456-7890"}
}

# Access nested values
email = person["contact"]["email"]
phone = person["contact"]["phone"]

print(f"Email: {email}")
print(f"Phone: {phone}")
# Out:
# Email: alice@email.com
# Phone: 123-456-7890

# %% [markdown]
# ### Question 5: Dictionary Methods
# Create a dictionary `grades = {"math": 85, "english": 92, "science": 88}`. Use dictionary methods to:
# - Get all keys
# - Get all values
# - Get all key-value pairs

# %%
# Question 5: Dictionary Methods
# Use .keys(), .values(), and .items() methods

grades = {"math": 85, "english": 92, "science": 88}

# Get all keys
all_keys = grades.keys()
print(f"Keys: {all_keys}")

# Get all values
all_values = grades.values()
print(f"Values: {all_values}")

# Get all key-value pairs
all_items = grades.items()
print(f"Items: {all_items}")
# Out:
# Keys: dict_keys(['math', 'english', 'science'])
# Values: dict_values([85, 92, 88])
# Items: dict_items([('math', 85), ('english', 92), ('science', 88)])

# %% [markdown]
# ### Question 6: Iterating Through Dictionaries
# Create a dictionary of 3 books with their authors. Write a loop to print each entry in the format: "Book Name by Author Name"

# %%
# Question 6: Iterating Through Dictionaries
# Create a dictionary of books and loop through them

books = {
    "1984": "George Orwell",
    "To Kill a Mockingbird": "Harper Lee",
    "The Great Gatsby": "F. Scott Fitzgerald"
}

# Iterate and print in "Title by Author" format
for title, author in books.items():
    print(f"{title} by {author}")
# Out:
# 1984 by George Orwell
# To Kill a Mockingbird by Harper Lee
# The Great Gatsby by F. Scott Fitzgerald
