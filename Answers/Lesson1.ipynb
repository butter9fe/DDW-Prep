# %% [markdown]
# # DDW Prep Lesson
# Your One-Stop guide to preparing for Term 3 Data Driven World!

# %% [markdown]
# ## Datatypes
#
# Python supports several fundamental data types:
# - **String**: Text data enclosed in quotes
# - **Boolean**: True or False values
# - **Integer**: Whole numbers
# - **Float**: Decimal numbers
#
# You can check the data type of any variable using the `type()` function.

# %% [markdown]
# ### String Datatype Example

# %%
player_name = "Steve"
print(player_name, type(player_name))
# Out:
# Steve <class 'str'>

# %%
greeting = "Steve says 'Minecraft is fun!' and chops a tree."
print(greeting)
# Out:
# Steve says 'Minecraft is fun!' and chops a tree.

# %%
story = """Once upon a time,
there was a Minecraft player named Steve.
He chopped some trees and built a house."""
print(story)

# %% [markdown]
# ### Boolean Datatype Example

# %%
has_weapon = True
print(has_weapon, type(has_weapon))

has_armour = False
print(has_armour, type(has_armour))
# Out:
# True <class 'bool'>
# False <class 'bool'>

# %% [markdown]
# ### Integer Datatype Example

# %%
diamonds = 18
print(diamonds, type(diamonds))
# Out:
# 18 <class 'int'>

# %% [markdown]
# ### Float Datatype Example

# %%
walk_speed = 4.5
print(walk_speed, type(walk_speed))
# Out:
# 4.5 <class 'float'>

# %% [markdown]
# ## Arithmetic
#
# Arithmetic operations are used to perform mathematical calculations. Python supports:
# - **Addition**: `+`
# - **Subtraction**: `-`
# - **Multiplication**: `*`
# - **Division**: `/`
# - **Exponentiation**: `**`
# - **Modulo**: `%` (remainder after division)
#
# Operations follow the standard order of operations (PEMDAS).

# %% [markdown]
# ### Arithmetic Example 1: Mixed Operations

# %%
vents = 1 + 2 * 3 - 4 / 5
print(vents)
# Out:
# 6.2

# %% [markdown]
# ### Arithmetic Example 2: Exponentiation and Modulo

# %%
sabotages = 2 ** 3 % 8
print(sabotages)
# Out:
# 0

# %% [markdown]
# ## Comparisons
#
# Comparison operators are used to compare two values. They return Boolean values (True or False):
# - **Equal to**: `==`
# - **Not equal to**: `!=`
# - **Greater than**: `>`
# - **Less than**: `<`
# - **Greater than or equal to**: `>=`
# - **Less than or equal to**: `<=`

# %% [markdown]
# ### Comparison Examples

# %%
imposters = 5
crewmates = 10

print(f"imposters == crewmates: {imposters == crewmates}")  # Is imposters = crewmates?
print(f"imposters != crewmates: {imposters != crewmates}")  # Is imposters not equal crewmates?
print(f"imposters < crewmates: {imposters < crewmates}")    # Is imposters less than crewmates?
print(f"imposters >= crewmates: {imposters >= crewmates}")  # Is imposters greater than or equal to crewmates?
print(f"imposters <= crewmates: {imposters <= crewmates}")  # Is imposters less than or equal to crewmates?
# Out:
# imposters == crewmates: False
# imposters != crewmates: True
# imposters < crewmates: True
# imposters >= crewmates: False
# imposters <= crewmates: True

# %% [markdown]
# ## Logical Operators
#
# Logical operators are used to combine conditional statements:
# - **and**: Returns True if both statements are true
# - **or**: Returns True if at least one statement is true
# - **not**: Returns the opposite boolean value

# %% [markdown]
# ### Logical Operator Examples

# %%
imposters = 2
crewmates = 15

# AND operator
a = imposters == 10 and crewmates == 10
print(f"imposters == 10 and crewmates == 10: {a}") # Are both imposters and crewmates = 10?

# OR operator
b = imposters == 2 or crewmates == 20 # Is either imposters = 2 or crewmates = 20?
print(f"imposters == 2 or crewmates == 20: {b}")

# NOT operator
c = not imposters > crewmates # Is it not true that imposters is greater than crewmates?
print(f"not imposters > crewmates: {c}")
# Out:
# imposters == 10 and crewmates == 10: False
# imposters == 2 or crewmates == 20: True
# not imposters > crewmates: True

# %% [markdown]
# ### Chained Comparator Examples

# %%
d = 10 <= crewmates <= 20
print(f"Is the number of crewmates between 10 and 20? {d}")

# You can also do it in the reverse direction
e = 20 >= crewmates >= 10
print(f"Is the number of crewmates between 10 and 20? {e}")

# AVOID THIS! It can make your logic hard to debug
f = 10 <= crewmates >= 20
print(f"Is the number of crewmates more than 10 and 20? {f}")
# Out:
# Is the number of crewmates between 10 and 20? True
# Is the number of crewmates between 10 and 20? True
# Is the number of crewmates more than 10 and 20? False

# %% [markdown]
# ## Lists
#
# A list is a collection of items in a specific order. Lists:
# - Are created using square brackets `[]`
# - Can contain different data types
# - Are indexed starting from 0
# - Support membership testing with `in` and `not in`

# %% [markdown]
# ### List Examples

# %%
player_info = ["Steve", True, 18, 4.5]
print(player_info)

# Access the first element (index 0)
print(player_info[0])
# Out:
# ['Steve', True, 18, 4.5]
# Steve

# %% [markdown]
# ### Membership Testing with Lists

# %%
player = "Steve"
print(f"'{player}' in player_info: {player in player_info}")

mob = "Creeper"
print(f"'{mob}' not in player_info: {mob not in player_info}")
# Out:
# 'Steve' in player_info: True
# 'Creeper' not in player_info: True

# %% [markdown]
# ## Variable Assignments
#
# Variable assignment is how we store values in memory:
# - **Basic assignment**: Assign a value to a variable
# - **Update assignment**: Modify a variable's value
# - **Simultaneous assignment**: Assign multiple values at once
# - **Swapping**: Exchange values between variables

# %% [markdown]
# ### Basic and Update Assignment

# %%
Sus = 1
print(f"imposters initial value: {Sus}")

Sus = Sus + 1
print(f"imposters after adding 1: {Sus}")
# Out:
# imposters initial value: 1
# imposters after adding 1: 2

# %% [markdown]
# ### Simultaneous Assignment and Swapping

# %%
imposters, crewmates = 1, 2
print(f"Before swap: imposters = {imposters}, crewmates = {crewmates}")

imposters, crewmates = crewmates, imposters
print(f"After swap: imposters = {imposters}, crewmates = {crewmates}")
# Out:
# Before swap: imposters = 1, crewmates = 2
# After swap: imposters = 2, crewmates = 1

# %% [markdown]
# ## Conditionals (if/elif/else)
#
# Conditional statements allow your program to make decisions:
# - **if**: Execute code if a condition is True
# - **elif**: Execute code if the previous condition was False and this condition is True
# - **else**: Execute code if all previous conditions were False
#
# You can also nest conditionals for more complex logic.

# %% [markdown]
# ### Conditional Example 1: Age Classification

# %%
age = 17

if age < 13:
    print("You are a child.")
elif age < 18:
    print("You are a teenager.")
elif age < 65:
    print("You are an adult.")
else:
    print("You are a senior.")
# Out:
# You are a teenager.

# %% [markdown]
# ### Conditional Example 2: Nested Conditions

# %%
age = 15
in_school = True

if 13 <= age <= 19:
    if in_school:
        print("You are a teenage student.")
    else:
        print("You are a teenager but not in school")
else:
    print("You are not a teenager.")
# Out:
# You are a teenage student.

# %% [markdown]
# ### Conditional Example 3: Multiple Conditions

# %%
is_raining = True
is_cold = True

# Using multiple if statements
print("Option 1: Multiple if statements")
if is_raining:
    print("Take an umbrella.")
if is_cold:
    print("Wear a warm coat.")

# Using if/elif
print("\nOption 2: Using if/elif")
if is_raining:
    print("Take an umbrella.")
elif is_cold:
    print("Wear a warm coat.")
# Out:
# Option 1: Multiple if statements
# Take an umbrella.
# Wear a warm coat.
#
# Option 2: Using if/elif
# Take an umbrella.

# %% [markdown]
# ## Loops
#
# Loops allow you to execute code repeatedly:
# - **for loop**: Iterate over a sequence (list, range, etc.)
# - **break**: Exit the loop prematurely
# - **continue**: Skip to the next iteration
#
# The `for` loop is commonly used with the `range()` function to iterate a specific number of times.

# %% [markdown]
# ### Loop Example with break Statement

# %%
Energy = 100

# Loop through each day of the week
for day in range(1, 8):
    print(f"Day {day}: Energy level is {Energy}.")
    Energy -= 20  # Decrease energy by 20 each day

    if Energy <= 0:
        break

day += 1  # Increment day to reflect the day when energy is depleted
print(f"Day {day}: Energy is depleted. Time to rest.")
# Out:
# Day 1: Energy level is 100.
# Day 2: Energy level is 80.
# Day 3: Energy level is 60.
# Day 4: Energy level is 40.
# Day 5: Energy level is 20.
# Day 6: Energy is depleted. Time to rest.

# %% [markdown]
# ## The Range Function
#
# The `range()` function generates a sequence of numbers:
# - **range(stop)**: Generates numbers from 0 to stop-1
# - **range(start, stop)**: Generates numbers from start to stop-1
# - **range(start, stop, step)**: Generates numbers from start to stop-1, incrementing by step
#
# The stop value is always exclusive (not included in the sequence).

# %% [markdown]
# ### Range Example with Step

# %%
print("Using range(1, 8, 2):")
for day in range(1, 8, 2):
    # Start at 1,
    # end at 8 (non-inclusive),
    # incremented by 2
    print(day)
# Out:
# Using range(1, 8, 2):
# 1
# 3
# 5
# 7

# %% [markdown]
# ### Additional Range Examples

# %%
# Example 1: range(stop)
print("range(5):")
for i in range(5):
    print(i)

# Example 2: range(start, stop)
print("\nrange(2, 7):")
for i in range(2, 7):
    print(i)
# Out:
# range(5):
# 0
# 1
# 2
# 3
# 4
#
# range(2, 7):
# 2
# 3
# 4
# 5
# 6

# %% [markdown]
# ### Question 1: Data Types
# Create variables for the following and use the `type()` function to verify their types:
# - Your name (string)
# - Your age (integer)
# - Your height in meters (float)
# - Whether you like programming (boolean)

# %%
# Question 1: Create variables for name, age, height, and a boolean
# Then use type() to check the type of each variable
# Replace the values below with your own data

name = "Your name here"
age = 0
height = 0.0
likes_programming = True

# Use type() to check the type of each variable
print(f"Name type: {type(name)}")
print(f"Age type: {type(age)}")
print(f"Height type: {type(height)}")
print(f"Likes programming type: {type(likes_programming)}")
# Out:
# Name type: <class 'str'>
# Age type: <class 'int'>
# Height type: <class 'float'>
# Likes programming type: <class 'bool'>

# %% [markdown]
# ### Question 2: Arithmetic Operations
# Write code to calculate:
# - The sum of 15 and 23
# - The product of 8 and 7
# - The remainder when 25 is divided by 4
# - The square of 9 (9 * 9)

# %%
# Question 2: Perform various arithmetic operations
# Complete each operation and print the result

sum_result = 15 + 23
print(f"Sum of 15 and 23: {sum_result}")

product_result = 8 * 7
print(f"Product of 8 and 7: {product_result}")

remainder_result = 25 % 4
print(f"Remainder of 25 divided by 4: {remainder_result}")

square_result = 9 * 9
print(f"Square of 9: {square_result}")
# Out:
# Sum of 15 and 23: 38
# Product of 8 and 7: 56
# Remainder of 25 divided by 4: 1
# Square of 9: 81

# %% [markdown]
# ### Question 3: Mixed Operations
# Create a variable `budget` with value 100. Perform the following operations:
# - Add 50 to the budget
# - Subtract 30 from the budget
# - Multiply by 2
# - Print the final result and its type

# %%
# Question 3: Perform operations on a budget variable
# Start with budget = 100, then add, subtract, multiply
# Print the result after each operation

budget = 100
print(f"Starting budget: {budget}")

budget = budget + 50
print(f"After adding 50: {budget}")

budget = budget - 30
print(f"After subtracting 30: {budget}")

budget = budget * 2
print(f"After multiplying by 2: {budget}")
print(f"Final result type: {type(budget)}")
# Out:
# Starting budget: 100
# After adding 50: 150
# After subtracting 30: 120
# After multiplying by 2: 240
# Final result type: <class 'int'>

# %% [markdown]
# ### Question 4: String Concatenation
# Create two variables: `first_name = "Steve"` and `last_name = "Jobs"`. Use the `+` operator to combine them into a full name string and print it.

# %%
# Question 4: String concatenation
# Combine first and last names using the + operator

first_name = "Steve"
last_name = "Jobs"

# Combine the names and print the result
full_name = first_name + " " + last_name
print(f"Full name: {full_name}")
# Out:
# Full name: Steve Jobs

# %% [markdown]
# ### Question 5: Type Conversion
# Convert the following and print the results:
# - Convert the string "42" to an integer
# - Convert the float 3.14 to an integer
# - Convert the integer 10 to a string
# - Convert the string "True" to a boolean (think about how Python handles this)

# %%
# Question 5: Type conversion
# Convert between different data types

# Convert string "42" to integer
str_number = "42"
int_number = int(str_number)
print(f"String '42' converted to int: {int_number}, type: {type(int_number)}")

# Convert float to integer
float_number = 3.14
converted_int = int(float_number)
print(f"Float 3.14 converted to int: {converted_int}, type: {type(converted_int)}")

# Convert integer to string
num = 10
converted_str = str(num)
print(f"Integer 10 converted to string: {converted_str}, type: {type(converted_str)}")

# Try converting string "True" to boolean (note: this is tricky!)
str_bool = "True"
# Note: bool("True") will always be True because any non-empty string is True!
print(f"String 'True' converted to bool: {bool(str_bool)}")
# Out:
# String '42' converted to int: 42, type: <class 'int'>
# Float 3.14 converted to int: 3, type: <class 'int'>
# Integer 10 converted to string: 10, type: <class 'str'>
# String 'True' converted to bool: True
