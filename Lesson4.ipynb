# %% [markdown]
# # Python Strings and Tuples
#
# Learn about two important data types: strings for text manipulation and tuples for immutable sequences.

# %% [markdown]
# ## Strings
#
# A string is a sequence of characters enclosed in quotes (single or double). Strings are:
# - **Immutable**: Cannot be changed after creation (you must create a new string)
# - **Iterable**: Can loop through each character
# - **Indexable**: Can access characters by position
# - **Sliceable**: Can extract substrings
#
# Strings are one of the most commonly used data types in Python.

# %% [markdown]
# ### Basic String Operations

# %%
player = "Alex"
print(player)  # This will print the String "Alex" as text

# %% [markdown]
# ### Strings are Immutable
#
# You cannot change individual characters in a string. This will raise an error:

# %%
# This will raise a TypeError
try:
    player[0] = "H"
except TypeError as e:
    print(f"Error: {e}")
    print("Strings are immutable - you cannot change individual characters!")

# %% [markdown]
# ### Iterating Through Strings

# %%
player = "Steve"

# Strings are Iterable - loop through each character
for character in player:
    print(character)
# This will print each character in the string "Steve" on a new line

# %% [markdown]
# ### String Indexing and Slicing
#
# You can access parts of a string using indices and slices.

# %%
player = "Steve"

# Indexing - access a single character
print(f"First character: {player[0]}")  # S
print(f"Second character: {player[1]}")  # t
print(f"Last character: {player[-1]}")  # e (negative index counts from the end)

# Slicing - extract a substring
print(f"Characters from index 1 to 4: {player[1:4]}")  # teve (end index is exclusive)
print(f"First 3 characters: {player[:3]}")  # Ste
print(f"Characters from index 2 onwards: {player[2:]}")  # eve

# %% [markdown]
# ### String Concatenation
#
# Combine strings using the `+` operator.

# %%
player = "Steve"

# String concatenation
player = player + " is my favorite player."
print(player)  # Steve is my favorite player.

# %% [markdown]
# ### String Methods
#
# Strings have many built-in methods for manipulation. Here are some commonly used ones:

# %%
player = "Steve is my favorite player."

# Convert to uppercase
print(player.upper())  # STEVE IS MY FAVORITE PLAYER

# Convert to lowercase
print(player.lower())  # steve is my favorite player.

# Replace text
print(player.replace("Alex", "Creeper"))  # Alex is my favorite player.

# Find the index of a substring
print(player.find("favorite"))  # 12

# Check if string starts with a substring
print(player.startswith("Steve"))  # True

# Check if string ends with a substring
print(player.endswith("character."))  # True

# Split string into a list
words = player.split(" ")
print(words)  # ['Steve', 'is', 'my', 'favorite', 'player.']

# %% [markdown]
# ### String Formatting
#
# There are several ways to format strings with variables.

# %%
name = "Steve"
diamonds = 18
walk_speed = 4.5

# Method 1: F-strings (Modern and recommended)
print(f"{name} has {diamonds} diamonds and walks at {walk_speed} m/s")

# Method 2: .format() method
print("{} has {} diamonds and walks at {} m/s".format(name, diamonds, walk_speed))

# Method 3: String concatenation
print(name + " has diamonds " + str(diamonds) + " and walks at " + str(walk_speed) + " m/s")

# %% [markdown]
# ### String Methods Reference
#
# For a comprehensive list of string methods, visit: https://www.w3schools.com/python/python_ref_string.asp
#
# This is highly recommended for your DDW project to find methods that suit your specific needs!

# %% [markdown]
# ## Tuples
#
# A tuple is an ordered collection of items enclosed in parentheses `()`. Tuples are:
# - **Immutable**: Cannot be changed after creation (like strings)
# - **Ordered**: Items have a defined order and can be accessed by index
# - **Can contain mixed types**: Like lists, tuples can contain any data type
# - **Iterable**: Can loop through items
#
# Tuples are lighter weight than lists and are used when data shouldn't change.

# %% [markdown]
# ### Basic Tuple Operations

# %%
numbers = (88, 1, 20)
print(numbers)  # This will print the tuple (88, 1, 20)

# %% [markdown]
# ### Tuples are Immutable
#
# You cannot change, add, or remove elements from a tuple after creation.

# %%
numbers = (88, 1, 20)

# This will raise a TypeError because tuples do not support item assignment
try:
    numbers[0] = 99
except TypeError as e:
    print(f"Error: {e}")
    print("Tuples are immutable - you cannot change elements!")

# %% [markdown]
# ### Tuples with Mixed Data Types

# %%
# Similar to lists, tuples can contain ANY data type
player_info = ("Steve", 88, True, 4.5)
print(player_info)  # This will print the tuple ("Steve", 88, True, 4.5)

# Access elements by type
print(f"Name (string): {player_info[0]}")
print(f"Number (int): {player_info[1]}")
print(f"Boolean: {player_info[2]}")
print(f"Height (float): {player_info[3]}")

# %% [markdown]
# ### Iterating Through Tuples

# %%
player_info = ("Steve", 88, True)

# Tuples are iterable (Similar to Lists)
for item in player_info:
    print(item)
# This will print each item in the tuple, each on a new line

# %% [markdown]
# ### Tuple Indexing and Slicing

# %%
player_info = ("Steve", 88, True, 4.5)

# Tuples also support indexing
print(f"First item: {player_info[0]}")  # Steve
print(f"Last item: {player_info[-1]}")  # 4.5

# Tuples also support slicing
print(f"Items from index 1 to 3: {player_info[1:3]}")  # (88, True)

# %% [markdown]
# ### Important: Single Element Tuples
#
# Single element tuples MUST have a trailing comma, otherwise Python treats them as regular values.

# %%
# Single element tuple - requires a comma
single_element_tuple = (88,)
print(f"Type: {type(single_element_tuple)}")
print(f"Value: {single_element_tuple}")  # (88,)

# Without the comma - this is NOT a tuple
not_a_tuple = (88)
print(f"\nType: {type(not_a_tuple)}")
print(f"Value: {not_a_tuple}")  # 88 (just an integer)

# Remember: Single element tuples need a comma!

# %% [markdown]
# ### Tuples vs Lists
#
# | Feature | Tuple | List |
# |---------|-------|------|
# | Mutable | ❌ No (immutable) | ✅ Yes (mutable) |
# | Syntax | `()` parentheses | `[]` square brackets |
# | Performance | Faster | Slower |
# | Use Case | Fixed data, function returns | Dynamic data, frequent changes |
# | Methods | Limited | Many modification methods |
#
# **Use tuples when:** Data shouldn't change, performance matters, or you need to use items as dictionary keys.
#
# **Use lists when:** You need to add, remove, or modify elements.

# %% [markdown]
# ### Tuple Unpacking
#
# A powerful feature of tuples is unpacking - assigning tuple elements to individual variables.

# %%
# Tuple unpacking
person = ("Steve", 18, 4.5)
name, age, height = person

print(f"Name: {name}")
print(f"Age: {age}")
print(f"Height: {height}")

# This is the same as:
# name = person[0]
# age = person[1]
# height = person[2]

# %% [markdown]
# ### Question 1: String Indexing
# Create a string `word = "Python"`. Print:
# - The first character
# - The last character
# - The character at index 2

# %%
# Create a string word = "Python"
# Access and print the first character, last character, and character at index 2

# Add your code here:

# %% [markdown]
# ### Question 2: String Slicing
# Using the string `sentence = "Learning Python is fun"`, extract and print:
# - The first 8 characters
# - The last 3 characters
# - Every other character starting from index 0

# %%
# Use the string sentence = "Learning Python is fun"
# Extract and print the first 8 characters, last 3 characters, and every other character

# Add your code here:

# %% [markdown]
# ### Question 3: String Methods
# Given the string `text = "Hello World"`, use string methods to:
# - Convert it to lowercase
# - Convert it to uppercase
# - Replace "World" with "Python"
# - Count how many times the letter "o" appears

# %%
# Use text = "Hello World"
# Apply string methods: lower(), upper(), replace(), and count()

# Add your code here:

# %% [markdown]
# ### Question 4: Iterating Through Strings
# Write a loop that iterates through the string `name = "Student"` and prints each character on a new line.

# %%
# Create name = "Student"
# Write a loop to iterate through each character and print it

# Add your code here:

# %% [markdown]
# ### Question 5: String Concatenation and Formatting
# Create two variables: `first = "Jane"` and `last = "Smith"`. Use:
# - Concatenation with `+` to create a full name
# - f-string formatting to create a greeting: "Hello, Jane Smith!"

# %%
# Create first = "Jane" and last = "Smith"
# Use + operator for concatenation
# Use f-string to create a greeting

# Add your code here:

# %% [markdown]
# ### Question 6: Tuple Basics
# Create a tuple `coordinates = (10, 20, 30)`. Try to modify the first element. What error do you get and why?

# %%
# Create a tuple coordinates = (10, 20, 30)
# Try to modify the first element and observe what happens

# Add your code here:
